# %%
import json
from xml.etree.ElementTree import Element, SubElement, Comment
from xml.etree import ElementTree
from xml.dom import minidom

# %%
with open("icd11.json") as fp:
    data = json.load(fp)

# %%
data
# Out:
# {'1D01.Y': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/121670633/other',
#   'title': 'Other specified infectious meningitis not elsewhere classified',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/121670633/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1D01.Y',
#   'score': 0.38856333,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>adhesive</em> arachnoiditis",
#     'score': 0.38856333,
#     'important': False}],
#   'descendants': []},
#  '1D80': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1208294714',
#   'title': "<em class='found'>Mumps</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1208294714',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1D80',
#   'score': 6.758152,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  '1D80.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2082214683',
#   'title': 'Mumps without complication',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2082214683',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1D80.0',
#   'score': 0.016169317,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "parotitis due to <em class='found'>mumps</em> <em class='found'>virus</em>",
#     'score': 0.016169317,
#     'important': False}],
#   'descendants': []},
#  '1D84.Y': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/157616931/other',
#   'title': 'Other specified viral conjunctivitis',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/157616931/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1D84.Y',
#   'score': 0.020447375,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>adenoviral</em> pharyngoconjunctivitis",
#     'score': 0.020447375,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>adenoviral</em> pharygoconjunctival fever",
#     'score': 0.0005633245,
#     'important': False}],
#   'descendants': []},
#  '1D9Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/237422666/unspecified',
#   'title': "Unspecified viral <em class='found'>infection</em> of unspecified site",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/237422666/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '01',
#   'theCode': '1D9Z',
#   'score': 0.29170686,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "viral <em class='found'>infection</em> NOS",
#     'score': 0.29170686,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "viral <em class='found'>infectious</em> disease",
#     'score': 0.0073033436,
#     'important': False}],
#   'descendants': []},
#  '1E32': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1235618695',
#   'title': 'Influenza, virus not identified',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1235618695',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E32',
#   'score': 0.011136478,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "influenzal sore <em class='found'>throat</em>",
#     'score': 0.011136478,
#     'important': False}],
#   'descendants': []},
#  '1E70': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2054716425',
#   'title': "<em class='found'>Smallpox</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2054716425',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E70',
#   'score': 7.3202853,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E71': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/160886685',
#   'title': "<em class='found'>Monkeypox</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/160886685',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E71',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E72': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1205745537',
#   'title': "<em class='found'>Cowpox</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1205745537',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E72',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E73': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1275065853',
#   'title': "<em class='found'>Vaccinia</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1275065853',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E73',
#   'score': 7.8906813,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E74': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/444002285',
#   'title': "<em class='found'>Buffalopox</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/444002285',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E74',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E75': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/111540068',
#   'title': "<em class='found'>Orf</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/111540068',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E75',
#   'score': 8.2321005,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E7Y': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2080431678/other',
#   'title': 'Other specified infections due to poxvirus',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2080431678/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E7Y',
#   'score': 0.0,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Tanapox</em> <em class='found'>virus</em> disease",
#     'score': 0.018399954,
#     'important': False}],
#   'descendants': []},
#  '1E90.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1667539108',
#   'title': "<em class='found'>Varicella</em> without complication",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1667539108',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E90.0',
#   'score': 0.013969322,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E90.Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1805574500/unspecified',
#   'title': "<em class='found'>Varicella</em>, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1805574500/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '01',
#   'theCode': '1E90.Z',
#   'score': 7.144347,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Varicella</em>",
#     'score': 7.144347,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Varicella</em> NOS",
#     'score': 7.144347,
#     'important': False}],
#   'descendants': []},
#  '1E91.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1659043996',
#   'title': "<em class='found'>Zoster</em> without complications",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1659043996',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E91.0',
#   'score': 0.012706249,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  '1E91.Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/523481501/unspecified',
#   'title': "<em class='found'>Zoster</em>, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/523481501/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '01',
#   'theCode': '1E91.Z',
#   'score': 6.4969716,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Zoster</em>",
#     'score': 6.4969716,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Zoster</em> NOS",
#     'score': 6.4969716,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Zona <em class='found'>zoster</em>",
#     'score': 0.5079803,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Herpes <em class='found'>zoster</em>",
#     'score': 0.5079803,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Herpes <em class='found'>zoster</em> of skin and mucous membranes",
#     'score': 1.6971102e-07,
#     'important': False}],
#   'descendants': []},
#  '1F00.10': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1188755650',
#   'title': 'Herpes simplex keratitis',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1188755650',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F00.10',
#   'score': 0.009270725,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Infectious <em class='found'>epithelial</em> keratitis",
#     'score': 0.009270725,
#     'important': False}],
#   'descendants': []},
#  '1F00.Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/248851702/unspecified',
#   'title': "<em class='found'>Herpes</em> <em class='found'>simplex</em> <em class='found'>infections</em>, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/248851702/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '01',
#   'theCode': '1F00.Z',
#   'score': 0.017039755,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Herpes</em> <em class='found'>simplex</em> <em class='found'>infections</em>",
#     'score': 0.017039755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'><em class='found'>Herpes</em>viral</em> <em class='found'>infection</em> due to <em class='found'>Herpes</em> <em class='found'>simplex</em>",
#     'score': 0.00013367175,
#     'important': False}],
#   'descendants': []},
#  '1F01': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1883970802',
#   'title': "<em class='found'>Roseola</em> <em class='found'>infantum</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1883970802',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F01',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1F02': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/410022648',
#   'title': 'Rubella',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/410022648',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F02',
#   'score': 0.53187305,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "German <em class='found'>measles</em>",
#     'score': 0.53187305,
#     'important': False}],
#   'descendants': []},
#  '1F02.2': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1478349286',
#   'title': "<em class='found'>Rubella</em> <em class='found'>without</em> <em class='found'>complication</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1478349286',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F02.2',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1F03': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1826431497',
#   'title': "<em class='found'>Measles</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1826431497',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F03',
#   'score': 6.803002,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  '1F03.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1503293914',
#   'title': "<em class='found'>Measles</em> <em class='found'>without</em> <em class='found'>complication</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1503293914',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F03.0',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '2A00.00': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/650534447',
#   'title': 'Glioblastoma of brain',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/650534447',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A00.00',
#   'score': 0.014528161,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Gliosarcoma</em> of brain",
#     'score': 0.014528161,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "monstrocellular <em class='found'>sarcoma</em> of unspecified site",
#     'score': 0.009772861,
#     'important': False}],
#   'descendants': []},
#  '2A00.10': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/290815825',
#   'title': 'Medulloblastoma of brain',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/290815825',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A00.10',
#   'score': 7.270913,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Neuroepithelioma</em>",
#     'score': 7.270913,
#     'important': True}],
#   'descendants': []},
#  '2A01.0Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/672106711/unspecified',
#   'title': 'Meningeal tumours, unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/672106711/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2A01.0Z',
#   'score': 6.2757235,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>meningioma</em> NOS",
#     'score': 6.2757235,
#     'important': True},
#    {'propertyId': 'IndexTerm',
#     'label': "benign <em class='found'>meningioma</em>",
#     'score': 0.49071142,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "haemangiopericytic <em class='found'>meningioma</em>",
#     'score': 0.49071142,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "mixed <em class='found'>meningioma</em>",
#     'score': 0.49071142,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "meningiotheliomatous <em class='found'>meningioma</em>",
#     'score': 0.49071142,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "benign intracranial <em class='found'>meningioma</em>",
#     'score': 0.012274793,
#     'important': False}],
#   'descendants': []},
#  '2A02.10': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/71413945',
#   'title': 'Malignant peripheral nerve sheath tumour',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/71413945',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A02.10',
#   'score': 0.14258404,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>neurofibrosarcoma</em>",
#     'score': 0.14258404,
#     'important': False}],
#   'descendants': []},
#  '2A20.2': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/336704235',
#   'title': "<em class='found'>Primary</em> <em class='found'>myelofibrosis</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/336704235',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A20.2',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '2A21.1Y': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1300710062/other',
#   'title': 'Other specified cutaneous mastocytosis',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1300710062/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A21.1Y',
#   'score': 0.0,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Diffuse</em> <em class='found'>cutaneous</em> <em class='found'>mastocytosis</em>",
#     'score': 0.019178659,
#     'important': True},
#    {'propertyId': 'IndexTerm',
#     'label': "Bullous <em class='found'>diffuse</em> <em class='found'>cutaneous</em> <em class='found'>mastocytosis</em>",
#     'score': 0.00014983327,
#     'important': False}],
#   'descendants': []},
#  '2A21.Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/691643472/unspecified',
#   'title': 'Mastocytosis, unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/691643472/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2A21.Z',
#   'score': 0.598853,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "malignant <em class='found'>mastocytoma</em>",
#     'score': 0.598853,
#     'important': False}],
#   'descendants': []},
#  '2A22': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1981398038',
#   'title': "<em class='found'>Other</em> and unspecified <em class='found'>myeloproliferative</em> <em class='found'>neoplasms</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1981398038',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A22',
#   'score': 0.016306596,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '2A37': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1684468291',
#   'title': 'Myelodysplastic syndrome, unclassifiable',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1684468291',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A37',
#   'score': 0.01073525,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "pre myelogenous <em class='found'>leukaemia</em>",
#     'score': 0.01073525,
#     'important': False}],
#   'descendants': []},
#  '2A60.35': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/631263622',
#   'title': 'Acute erythroid leukaemia',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/631263622',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A60.35',
#   'score': 2.2984757e-07,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>acute</em> <em class='found'>myeloid</em> <em class='found'>leukaemia</em> M6 (a)(b)",
#     'score': 2.2984757e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>acute</em> <em class='found'>myeloid</em> <em class='found'>leukaemia</em>, m6 type",
#     'score': 2.2984757e-07,
#     'important': False}],
#   'descendants': []},
#  '2A60.38': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/585339631',
#   'title': "<em class='found'>Acute</em> <em class='found'>panmyelosis</em> with <em class='found'>myelofibrosis</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/585339631',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A60.38',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Acute</em> <em class='found'>panmyelosis</em> with <em class='found'>myelofibrosis</em> in complete remission",
#     'score': 2.85141e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>acute</em> <em class='found'>panmyelosis</em> with <em class='found'>myelofibrosis</em> without mention of remission",
#     'score': 1.2127495e-10,
#     'important': False}],
#   'descendants': []},
#  '2A60.39': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1988933820',
#   'title': "<em class='found'>Myeloid</em> <em class='found'>sarcoma</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1988933820',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A60.39',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>myeloid</em> <em class='found'>sarcoma</em> NOS",
#     'score': 0.6210235,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>myeloid</em> <em class='found'>sarcoma</em> disease",
#     'score': 0.015530984,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Myeloid</em> <em class='found'>sarcoma</em> in complete remission",
#     'score': 0.00012133581,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>myeloid</em> <em class='found'>sarcoma</em> without mention of remission",
#     'score': 2.074125e-07,
#     'important': False}],
#   'descendants': []},
#  '2A70.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/971902553',
#   'title': "<em class='found'>B</em> <em class='found'>Lymphoblastic</em> <em class='found'>leukaemia</em> or <em class='found'>lymphoma</em>, not elsewhere classified",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/971902553',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A70.0',
#   'score': 1.2713154e-10,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  '2A83.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/45411563',
#   'title': "<em class='found'>Monoclonal</em> <em class='found'>gammopathy</em> of <em class='found'>undetermined</em> <em class='found'>significance</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/45411563',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A83.0',
#   'score': 0.00019874395,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "MGUS - [<em class='found'>monoclonal</em> <em class='found'>gammopathy</em> of <em class='found'>undetermined</em> <em class='found'>significance</em>]",
#     'score': 3.3897737e-07,
#     'important': False}],
#   'descendants': []},
#  '2A83.1': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/526287100',
#   'title': 'Plasma cell myeloma',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/526287100',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A83.1',
#   'score': 0.5657168,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Medullary <em class='found'>plasmacytoma</em>",
#     'score': 0.5657168,
#     'important': False}],
#   'descendants': []},
#  '2A83.2': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1811140613',
#   'title': "Solitary <em class='found'>plasmacytoma</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1811140613',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A83.2',
#   'score': 7.2364564,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Plasmacytoma</em> NOS",
#     'score': 7.2364564,
#     'important': True},
#    {'propertyId': 'IndexTerm',
#     'label': "Solitary <em class='found'>plasmacytoma</em> of bone",
#     'score': 0.014149065,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Primary <em class='found'>plasmacytoma</em> of bone",
#     'score': 0.014149065,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Solitary <em class='found'>plasmacytoma</em> in complete remission",
#     'score': 0.00011053957,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "solitary <em class='found'>plasmacytoma</em> without mention of remission",
#     'score': 1.8896898e-07,
#     'important': False}],
#   'descendants': []},
#  '2B33.4': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1385484871',
#   'title': 'Leukaemia, unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1385484871',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': True,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B33.4',
#   'score': 0.0,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Acute</em> <em class='found'>mixed</em> <em class='found'>lineage</em> <em class='found'>leukaemia</em>",
#     'score': 0.00016656831,
#     'important': True}],
#   'descendants': []},
#  '2B33.5': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/474972159',
#   'title': 'Malignant lymphoma, not elsewhere classified',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/474972159',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': True,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B33.5',
#   'score': 0.0001163646,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Lymphoma of <em class='found'>central</em> <em class='found'>nervous</em> <em class='found'>system</em>",
#     'score': 0.0001163646,
#     'important': False}],
#   'descendants': []},
#  '2B50.Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1625755389/unspecified',
#   'title': "<em class='found'>Chondrosarcoma</em> of bone and articular cartilage of unspecified sites",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1625755389/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2B50.Z',
#   'score': 0.14258404,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>chondrosarcoma</em> NOS",
#     'score': 0.14258404,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>chondrosarcoma</em> of unspecified site",
#     'score': 0.014528161,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Chondrosarcoma</em>, primary site",
#     'score': 0.00045400503,
#     'important': False}],
#   'descendants': []},
#  '2B5J': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1128819057',
#   'title': 'Malignant miscellaneous tumours of bone or articular cartilage of other or unspecified sites',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1128819057',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B5J',
#   'score': 0.009772861,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>sarcoma</em> of mandible",
#     'score': 0.009772861,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "odontogenic <em class='found'>sarcoma</em> of mandible",
#     'score': 0.009772861,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>sarcoma</em> of unspecified site",
#     'score': 0.009772861,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Odontogenic <em class='found'>sarcoma</em> of unspecified site",
#     'score': 0.009772861,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Odontogenic <em class='found'>carcinosarcoma</em> of mandible",
#     'score': 0.00045400503,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Odontogenic <em class='found'>fibrosarcoma</em> of mandible",
#     'score': 0.00045400503,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>fibrosarcoma</em> of mandible",
#     'score': 0.0004025231,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>odontosarcoma</em> of mandible",
#     'score': 0.0004025231,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>fibrodentinosarcoma</em> of mandible",
#     'score': 0.0004025231,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>odontosarcoma</em> of unspecified site",
#     'score': 0.0004025231,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic fibro-<em class='found'>odontosarcoma</em> of mandible",
#     'score': 0.00035104115,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Odontogenic <em class='found'>sarcoma</em> of upper jaw",
#     'score': 7.635048e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>sarcoma</em> of upper jaw",
#     'score': 7.554607e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Ameloblastic <em class='found'>fibrosarcoma</em> upper jaw bone",
#     'score': 5.356463e-09,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Odontogenic <em class='found'>fibrosarcoma</em> of bone of upper jaw",
#     'score': 5.356463e-09,
#     'important': False}],
#   'descendants': []},
#  '2C10.0': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1663659989',
#   'title': 'Adenocarcinoma of pancreas',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1663659989',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C10.0',
#   'score': 8.468355e-05,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Intraductal <em class='found'>papillary</em>-mucinous <em class='found'>carcinoma</em> of pancreas",
#     'score': 8.468355e-05,
#     'important': False}],
#   'descendants': []},
#  '2C10.1': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1421495979',
#   'title': 'Neuroendocrine neoplasms of pancreas',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1421495979',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C10.1',
#   'score': 0.015425717,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Pancreatic hypersecretion of <em class='found'>somatostatin</em>",
#     'score': 0.015425717,
#     'important': False}],
#   'descendants': []},
#  '2C12.00': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1097637010',
#   'title': "Combined hepatocellular-<em class='found'>cholangiocarcinoma</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1097637010',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C12.00',
#   'score': 0.11480601,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Hepatocholangiocarcinoma</em>",
#     'score': 0.11480601,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "hepatocellular <em class='found'>carcinoma</em> with cholangio<em class='found'>carcinoma</em>",
#     'score': 0.0069884676,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "combined hepatocellular <em class='found'>carcinoma</em> and cholangio<em class='found'>carcinoma</em>",
#     'score': 5.3730106e-05,
#     'important': False}],
#   'descendants': []},
#  '2C12.01': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1556608523',
#   'title': "<em class='found'>Hepatoblastoma</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1556608523',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C12.01',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '2C12.02': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1294035808',
#   'title': "Hepatocellular <em class='found'>carcinoma</em> of liver",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1294035808',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C12.02',
#   'score': 0.27312663,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "hepatocholangiolitic <em class='found'>carcinoma</em>",
#     'score': 0.27312663,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "hepatocellular <em class='found'>carcinoma</em>, NOS",
#     'score': 0.2681027,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Hepatocellular <em class='found'>carcinoma</em>",
#     'score': 0.2681027,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>hepatocarcinoma</em>",
#     'score': 0.11480601,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>carcinoma</em> of liver, specified as primary",
#     'score': 0.0068393596,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "hepatic cell <em class='found'>carcinoma</em>",
#     'score': 0.0068393596,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary <em class='found'>carcinoma</em> of liver",
#     'score': 0.0068393596,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "HCC - [hepatocellular <em class='found'>carcinoma</em>]",
#     'score': 0.0068393596,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "liver cell <em class='found'>carcinoma</em>",
#     'score': 0.0068393596,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary hepatocellular <em class='found'>carcinoma</em>",
#     'score': 0.0068393596,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "hepatic cellular <em class='found'>carcinoma</em>",
#     'score': 0.0068393596,
#     'important': False}],
#   'descendants': []},
#  '2C20.3': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2007774165',
#   'title': "<em class='found'>Olfactory</em> <em class='found'>neuroblastoma</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2007774165',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C20.3',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  '1A02': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2080365623',
#   'title': 'Intestinal infections due to Shigella',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2080365623',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1A02',
#   'score': 0.013016755,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "infection due to <em class='found'>bacillus</em> shiga-kruse",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "dysentery due to <em class='found'>bacillus</em> shiga-kruse",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "infection due to <em class='found'>bacillus</em> shiga",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "dysentery due to <em class='found'>bacillus</em> schmitz",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "dysentery due to <em class='found'>bacillus</em> schmitz-stutzer",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "dysentery due to <em class='found'>bacillus</em> shiga",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "dysentery due to <em class='found'>bacillus</em> flexneri",
#     'score': 0.013016755,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>bacillus</em> flexner infection",
#     'score': 0.013016755,
#     'important': False}],
#   'descendants': []},
#  '1A08': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1780040028',
#   'title': 'Paratyphoid Fever',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1780040028',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1A08',
#   'score': 0.0,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>salmonella</em> infection <em class='found'>paratyphi</em> <em class='found'>C</em>",
#     'score': 0.0001786814,
#     'important': False}],
#   'descendants': []},
#  '1C85': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/961032639',
#   'title': 'Japanese encephalitis',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/961032639',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1C85',
#   'score': 0.0,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Japanese</em> <em class='found'>encephalitis</em> <em class='found'>virus</em> disease",
#     'score': 0.00016142741,
#     'important': False}],
#   'descendants': []},
#  '1E50.1': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1337277167',
#   'title': 'Acute hepatitis B',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1337277167',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1E50.1',
#   'score': 1.00138495e-10,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Acute <em class='found'>hepatitis</em> B with <em class='found'>Hepatitis</em> <em class='found'>D</em> <em class='found'>virus</em> co-infection",
#     'score': 1.00138495e-10,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Acute <em class='found'>hepatitis</em> B without <em class='found'>Hepatitis</em> <em class='found'>D</em> <em class='found'>virus</em> co-infection",
#     'score': 1.2223937e-14,
#     'important': False}],
#   'descendants': []},
#  '1E51.0Z': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/352087872/unspecified',
#   'title': 'Chronic hepatitis B, unspecified',
# ...
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '13',
#   'theCode': 'DA01.11',
#   'score': 0.02915094,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>oropharyngeal</em> mucositis NOS",
#     'score': 0.02915094,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "viral <em class='found'>oropharyngeal</em> mucositis",
#     'score': 0.0009109669,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "radiation-induced <em class='found'>oropharyngeal</em> mucositis",
#     'score': 0.0008016814,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "drug-induced <em class='found'>oropharyngeal</em> mucositis",
#     'score': 0.0008016814,
#     'important': False}],
#   'descendants': []},
#  'DA21.Y': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/581725607/other',
#   'title': "Other specified motility disorders of <em class='found'>oesophagus</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/581725607/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '13',
#   'theCode': 'DA21.Y',
#   'score': 0.14466037,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Megaoesophagus</em>",
#     'score': 0.14466037,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Idiopathic <em class='found'>megaoesophagus</em>",
#     'score': 0.014785363,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Secondary motility disorders of <em class='found'>oesophagus</em>",
#     'score': 6.4817585e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Certain specified motility disorder of <em class='found'>oesophagus</em>",
#     'score': 6.4817585e-05,
#     'important': False}],
#   'descendants': []},
#  'LB11&XA4J67': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2066788055 & http://id.who.int/icd/release/11/2019-04/mms/2116804027',
#   'title': "Congenital diverticulum of <em class='found'>pharynx</em> [Oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2066788055',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '20',
#   'theCode': 'LB11&XA4J67',
#   'score': 0.012867233,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Pharyngeal</em> pouch [<em class='found'>Oropharynx</em>]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Pharyngeal</em> pouch [<em class='found'>Oropharynx</em>, NOS]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticula [<em class='found'>Oropharynx</em>]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticula [<em class='found'>Oropharynx</em>, NOS]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulitis [<em class='found'>Oropharynx</em>]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulitis [<em class='found'>Oropharynx</em>, NOS]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulum [<em class='found'>Oropharynx</em>]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulum [<em class='found'>Oropharynx</em>, NOS]",
#     'score': 0.012867233,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Congenital diverticulum of <em class='found'>pharynx</em> [Oro<em class='found'>pharynx</em>, NOS]",
#     'score': 9.814277e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "congenital <em class='found'>pharyngeal</em> pouch [<em class='found'>Oropharynx</em>]",
#     'score': 9.814277e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "congenital <em class='found'>pharyngeal</em> pouch [<em class='found'>Oropharynx</em>, NOS]",
#     'score': 9.814277e-05,
#     'important': False}],
#   'descendants': []},
#  'LB11&XA8RX5': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2066788055 & http://id.who.int/icd/release/11/2019-04/mms/1097954495',
#   'title': "Congenital diverticulum of <em class='found'>pharynx</em> [<em class='found'>Lateral</em> <em class='found'>wall</em> of oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2066788055',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '20',
#   'theCode': 'LB11&XA8RX5',
#   'score': 2.1554041e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Pharyngeal</em> pouch [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.1554041e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticula [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.1554041e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulitis [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.1554041e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulum [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.1554041e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "congenital <em class='found'>pharyngeal</em> pouch [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 9.250162e-11,
#     'important': False}],
#   'descendants': []},
#  'LB11&XA8659': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2066788055 & http://id.who.int/icd/release/11/2019-04/mms/1630516979',
#   'title': "Congenital diverticulum of <em class='found'>pharynx</em> [<em class='found'>Posterior</em> <em class='found'>wall</em> of oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2066788055',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '20',
#   'theCode': 'LB11&XA8659',
#   'score': 2.2837042e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Pharyngeal</em> pouch [<em class='found'>Posterior</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.2837042e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticula [<em class='found'>Posterior</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.2837042e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulitis [<em class='found'>Posterior</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.2837042e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pharyngeal</em> diverticulum [<em class='found'>Posterior</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 2.2837042e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "congenital <em class='found'>pharyngeal</em> pouch [<em class='found'>Posterior</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 9.811325e-11,
#     'important': False}],
#   'descendants': []},
#  'MD21': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1091154582',
#   'title': "Haemorrhage from <em class='found'>throat</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1091154582',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '21',
#   'theCode': 'MD21',
#   'score': 0.4451509,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>throat</em> haemorrhage",
#     'score': 0.4451509,
#     'important': False}],
#   'descendants': []},
#  'MD93': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/968461848',
#   'title': 'Dysphagia',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/968461848',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '21',
#   'theCode': 'MD93',
#   'score': 0.0009109669,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Dysphagia, <em class='found'>oropharyngeal</em> phase",
#     'score': 0.0009109669,
#     'important': False}],
#   'descendants': []},
#  'ND72.2Y&XA4J67': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/other & http://id.who.int/icd/release/11/2019-04/mms/2116804027',
#   'title': "Other specified foreign body in <em class='found'>pharynx</em> [Oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '22',
#   'theCode': 'ND72.2Y&XA4J67',
#   'score': 1.68886e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Other specified foreign body in <em class='found'>pharynx</em> [Oro<em class='found'>pharynx</em>, NOS]",
#     'score': 1.68886e-07,
#     'important': False}],
#   'descendants': []},
#  'ND72.2Y&XA8RX5': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/other & http://id.who.int/icd/release/11/2019-04/mms/1097954495',
#   'title': "Other specified foreign body in <em class='found'>pharynx</em> [<em class='found'>Lateral</em> <em class='found'>wall</em> of oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '22',
#   'theCode': 'ND72.2Y&XA8RX5',
#   'score': 1.1052527e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  'ND72.2Y&XA8659': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/other & http://id.who.int/icd/release/11/2019-04/mms/1630516979',
#   'title': "Other specified foreign body in <em class='found'>pharynx</em> [<em class='found'>Posterior</em> <em class='found'>wall</em> of oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '22',
#   'theCode': 'ND72.2Y&XA8659',
#   'score': 1.172151e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  'ND72.2Z&XA4J67': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/unspecified & http://id.who.int/icd/release/11/2019-04/mms/2116804027',
#   'title': "Foreign body in <em class='found'>pharynx</em>, unspecified [Oro<em class='found'>pharynx</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '22',
#   'theCode': 'ND72.2Z&XA4J67',
#   'score': 9.814277e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>pharynx</em>, unspecified [Oro<em class='found'>pharynx</em>, NOS]",
#     'score': 9.814277e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>pharynx</em> [Oro<em class='found'>pharynx</em>]",
#     'score': 9.814277e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>pharynx</em> [Oro<em class='found'>pharynx</em>, NOS]",
#     'score': 9.814277e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>nasopharynx</em> [<em class='found'>Oropharynx</em>]",
#     'score': 9.615383e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>nasopharynx</em> [<em class='found'>Oropharynx</em>, NOS]",
#     'score': 9.615383e-05,
#     'important': False}],
#   'descendants': []},
#  'ND72.2Z&XA8RX5': {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/unspecified & http://id.who.int/icd/release/11/2019-04/mms/1097954495',
#   'title': 'Foreign body in pharynx, unspecified [Lateral wall of oropharynx]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1479200261/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '22',
#   'theCode': 'ND72.2Z&XA8RX5',
#   'score': 8.560121e-11,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>nasopharynx</em> [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>oropharynx</em>]",
#     'score': 8.560121e-11,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Foreign body in <em class='found'>nasopharynx</em> [<em class='found'>Lateral</em> <em class='found'>wall</em> of <em class='found'>mesopharynx</em>]",
#     'score': 8.560121e-11,
#     'important': False}],
#   'descendants': []},
#  ...}

# %%
[it for it in data.values() if  not it['isLeaf']]
# Out:
# [{'id': 'http://id.who.int/icd/release/11/2019-04/mms/1208294714',
#   'title': "<em class='found'>Mumps</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1208294714',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1D80',
#   'score': 6.758152,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/410022648',
#   'title': 'Rubella',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/410022648',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F02',
#   'score': 0.53187305,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "German <em class='found'>measles</em>",
#     'score': 0.53187305,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1826431497',
#   'title': "<em class='found'>Measles</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1826431497',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1F03',
#   'score': 6.803002,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1099674056',
#   'title': "Precursor <em class='found'>B</em>-lymphoblastic neoplasms",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1099674056',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A70',
#   'score': 0.010400967,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/135549215',
#   'title': 'Vitamin B3 deficiency',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/135549215',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5B5C',
#   'score': 0.573345,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>nicotinamide</em> deficiency",
#     'score': 0.573345,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1327154972',
#   'title': "<em class='found'>Mature</em> <em class='found'>T</em>-<em class='found'>cell</em> <em class='found'>lymphoma</em>, specified <em class='found'>types</em>, <em class='found'>nodal</em> or <em class='found'>systemic</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1327154972',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2A90',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1046496266',
#   'title': "Primary cutaneous CD-30 positive T-cell <em class='found'>lymphoproliferative</em> <em class='found'>disorders</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1046496266',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B03',
#   'score': 8.714051e-15,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/535489185',
#   'title': 'Hereditary thrombophilia',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/535489185',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '03',
#   'theCode': '3B61.0',
#   'score': 0.021444282,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>antithrombin</em> deficiency",
#     'score': 0.021444282,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Prothrombin</em> gene mutation",
#     'score': 0.0006701338,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/216625985',
#   'title': 'Langerhans cell histiocytosis',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/216625985',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B31.2',
#   'score': 0.6815038,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Histiocytosis</em> <em class='found'>X</em>",
#     'score': 0.6815038,
#     'important': True}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1987089698',
#   'title': "<em class='found'>Turner</em> <em class='found'>syndrome</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1987089698',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '20',
#   'theCode': 'LD50.0',
#   'score': 0.642211,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': True,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Ullrich-<em class='found'>Turner</em> <em class='found'>syndrome</em>",
#     'score': 0.51393825,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1220564554 & http://id.who.int/icd/release/11/2019-04/mms/39079517',
#   'title': 'Trichomoniasis [Connective, subcutaneous and other soft tissues of uterus]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1220564554',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '01',
#   'theCode': '1A92&XA0KR7',
#   'score': 2.5606966e-19,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>infection</em> by trichomonas [Connective, subcutaneous and other <em class='found'>soft</em> <em class='found'>tissues</em> of uterus]",
#     'score': 2.5606966e-19,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "trichomonas <em class='found'>infection</em> [Connective, subcutaneous and other <em class='found'>soft</em> <em class='found'>tissues</em> of uterus]",
#     'score': 2.5606966e-19,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/915779102/other & http://id.who.int/icd/release/11/2019-04/mms/1953208837',
#   'title': "<em class='found'>Other</em> specified <em class='found'><em class='found'>lung</em></em> infections [<em class='found'>Connective</em>, <em class='found'>subcutaneous</em> and <em class='found'>other</em> <em class='found'>soft</em> <em class='found'>tissues</em> of <em class='found'><em class='found'>lung</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/915779102/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '12',
#   'theCode': 'CA4Y&XA2PV7',
#   'score': 1.2389858e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/915779102/unspecified & http://id.who.int/icd/release/11/2019-04/mms/1953208837',
#   'title': "<em class='found'>Lung</em> infections, unspecified [<em class='found'>Connective</em>, <em class='found'>subcutaneous</em> and <em class='found'>other</em> <em class='found'>soft</em> <em class='found'>tissues</em> of <em class='found'>lung</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/915779102/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '12',
#   'theCode': 'CA4Z&XA2PV7',
#   'score': 1.2309043e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>pulmonary</em> infection NOS [<em class='found'>Connective</em>, <em class='found'>subcutaneous</em> and <em class='found'>other</em> <em class='found'>soft</em> <em class='found'>tissues</em> of <em class='found'>lung</em>]",
#     'score': 3.7564218e-19,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1459455953/unspecified & http://id.who.int/icd/release/11/2019-04/mms/39079517',
#   'title': "Inflammatory <em class='found'>disorders</em> of the female genital tract, unspecified [Connective, subcutaneous and other <em class='found'>soft</em> <em class='found'>tissues</em> of uterus]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1459455953/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '16',
#   'theCode': 'GA0Z&XA0KR7',
#   'score': 1.3954304e-36,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/951863576 & http://id.who.int/icd/release/11/2019-04/mms/1851292761',
#   'title': "Unspecified malignant epithelial neoplasm of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em> [<em class='found'>Bones</em> of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/951863576',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C21.2&XA6EQ1',
#   'score': 7.320488e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/621800828/other & http://id.who.int/icd/release/11/2019-04/mms/1851292761',
#   'title': "Other specified malignant neoplasm of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em> [<em class='found'>Bones</em> of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/621800828/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C21.Y&XA6EQ1',
#   'score': 7.320488e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/621800828/unspecified & http://id.who.int/icd/release/11/2019-04/mms/1851292761',
#   'title': "Malignant neoplasms of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em>, unspecified [<em class='found'>Bones</em> of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/621800828/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2C21.Z&XA6EQ1',
#   'score': 1.7883652e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Malignant neoplasms of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em> [<em class='found'>Bones</em> of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em>]",
#     'score': 1.7883652e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary malignant neoplasm of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em> [<em class='found'>Bones</em> of <em class='found'><em class='found'>middle</em></em> <em class='found'><em class='found'>ear</em></em>]",
#     'score': 7.320488e-11,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1872149350 & http://id.who.int/icd/release/11/2019-04/mms/1902757709',
#   'title': "Malignant neoplasm of <em class='found'>orbit</em> [<em class='found'>Orbital</em> bone]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1872149350',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D04&XA8E69',
#   'score': 0.013360814,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>orbital</em> cancer [<em class='found'>Orbital</em> bone]",
#     'score': 0.013360814,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>intraorbital</em> cancer [<em class='found'>Orbital</em> bone]",
#     'score': 7.8163306e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary malignant neoplasm of <em class='found'>orbit</em> [<em class='found'>Orbital</em> bone]",
#     'score': 7.80409e-11,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/24927785 & http://id.who.int/icd/release/11/2019-04/mms/1851292761',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in <em class='found'>other</em> specified respiratory organs [Bones of <em class='found'>middle</em> <em class='found'>ear</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/24927785',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D73&XA6EQ1',
#   'score': 1.8384159e-24,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of <em class='found'>other</em> or unspecified respiratory organs [Bones of <em class='found'>middle</em> <em class='found'>ear</em>]",
#     'score': 1.8384159e-24,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1052510516 & http://id.who.int/icd/release/11/2019-04/mms/1851292761',
#   'title': "Personal history of <em class='found'>malignant</em> <em class='found'>neoplasm</em> of respiratory or intrathoracic organs <em class='found'>other</em> than the digestive organs, trachea, bronchus or lung [Bones of middle ear]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1052510516',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '24',
#   'theCode': 'QC40.2&XA6EQ1',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/414847181 & http://id.who.int/icd/release/11/2019-04/mms/1851292761',
#   'title': "Family history of <em class='found'>malignant</em> <em class='found'>neoplasm</em> of respiratory or intrathoracic organs <em class='found'>other</em> than digestive organs, trachea, bronchus or lung [Bones of <em class='found'>middle</em> <em class='found'>ear</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/414847181',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '24',
#   'theCode': 'QC61.2&XA6EQ1',
#   'score': 0.0,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/1518540905',
#   'title': "<em class='found'>Malignant</em> <em class='found'>phyllodes</em> <em class='found'>tumour</em> of <em class='found'><em class='found'>breast</em></em> [Upper <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA1NS5',
#   'score': 1.9398495e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/1414408665',
#   'title': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Axillary</em> <em class='found'>tail</em> of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA3PG5',
#   'score': 9.725189e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/2122691723',
#   'title': "<em class='found'>Malignant</em> <em class='found'>phyllodes</em> <em class='found'>tumour</em> of <em class='found'><em class='found'>breast</em></em> [Lower <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA3UY3',
#   'score': 1.9398495e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/1917582581',
#   'title': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Central</em> <em class='found'>portion</em> of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA0US1',
#   'score': 9.881257e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/931266332',
#   'title': "<em class='found'>Malignant</em> <em class='found'>phyllodes</em> <em class='found'>tumour</em> of <em class='found'><em class='found'>breast</em></em> [Lateral half of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA9CM2',
#   'score': 9.4570976e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/672601776',
#   'title': "<em class='found'>Malignant</em> <em class='found'>phyllodes</em> <em class='found'>tumour</em> of <em class='found'><em class='found'>breast</em></em> [Medial half of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA3JH6',
#   'score': 9.4570976e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/334241346',
#   'title': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Upper</em> <em class='found'>inner</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA3LS6',
#   'score': 1.0225988e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Upper</em> <em class='found'>inner</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#     'score': 1.0225988e-14,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/442894934',
#   'title': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Upper</em> <em class='found'>outer</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA2Q54',
#   'score': 1.0241728e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Upper</em> <em class='found'>outer</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#     'score': 1.0241728e-14,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/1035786178',
#   'title': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Lower</em> <em class='found'>inner</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA0VX8',
#   'score': 1.01687584e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Lower</em> <em class='found'>inner</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#     'score': 1.01687584e-14,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/79985282',
#   'title': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Lower</em> <em class='found'>outer</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA94U2',
#   'score': 1.0184419e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Malignant phyllodes tumour of <em class='found'><em class='found'>breast</em></em> [<em class='found'>Lower</em> <em class='found'>outer</em> <em class='found'>quadrant</em> of <em class='found'><em class='found'>breast</em></em>]",
#     'score': 1.0184419e-14,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/147026376 & http://id.who.int/icd/release/11/2019-04/mms/831985561',
#   'title': "<em class='found'>Malignant</em> <em class='found'>phyllodes</em> <em class='found'>tumour</em> of <em class='found'>breast</em> [<em class='found'>Breast</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/147026376',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2C63&XA12C1',
#   'score': 0.00011524481,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>phyllodes</em> <em class='found'>tumour</em> of <em class='found'>breast</em> [<em class='found'>Breast</em> NOS]",
#     'score': 0.00011524481,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/774170412/unspecified & http://id.who.int/icd/release/11/2019-04/mms/720455085',
#   'title': 'Malignant neoplasms of rectosigmoid junction, unspecified [Rectosigmoid junction]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/774170412/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2B91.Z&XA33J5',
#   'score': 0.00011700394,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>rectosigmoid</em> colon cancer [<em class='found'>Rectosigmoid</em> <em class='found'>junction</em>]",
#     'score': 0.00011700394,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>rectosigmoid</em> colon cancer [<em class='found'>Rectosigmoid</em> <em class='found'>junction</em>, NOS]",
#     'score': 0.00011700394,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/720455085',
#   'title': 'Malignant neoplasm metastasis in large intestine [Rectosigmoid junction]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA33J5',
#   'score': 6.516135e-15,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Rectosigmoid</em> <em class='found'>colon</em>]",
#     'score': 6.516135e-15,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [<em class='found'>Rectosigmoid</em> <em class='found'>colon</em>]",
#     'score': 6.516135e-15,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Rectosigmoid</em> <em class='found'>colon</em>]",
#     'score': 6.516135e-15,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [<em class='found'>Rectosigmoid</em> <em class='found'>colon</em>]",
#     'score': 6.516135e-15,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [Rectum and <em class='found'>sigmoid</em> <em class='found'>colon</em>]",
#     'score': 2.6102455e-19,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [Rectum and <em class='found'>sigmoid</em> <em class='found'>colon</em>]",
#     'score': 2.6102455e-19,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [Rectum and <em class='found'>sigmoid</em> <em class='found'>colon</em>]",
#     'score': 2.6102455e-19,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [Rectum and <em class='found'>sigmoid</em> <em class='found'>colon</em>]",
#     'score': 2.6102455e-19,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/655574575/unspecified & http://id.who.int/icd/release/11/2019-04/mms/274476426',
#   'title': 'Malignant neoplasms of anus or anal canal, unspecified [Sphincter ani muscle]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/655574575/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2C00.Z&XA3ML6',
#   'score': 9.6966e-05,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>cancer</em> of anus [<em class='found'>Anal</em> sphincter]",
#     'score': 9.6966e-05,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/655574575/unspecified & http://id.who.int/icd/release/11/2019-04/mms/1594277606',
#   'title': 'Malignant neoplasms of anus or anal canal, unspecified [Anal Canal]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/655574575/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2C00.Z&XA39S6',
#   'score': 9.6966e-05,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>cancer</em> of anus [<em class='found'>Anal</em> Canal]",
#     'score': 9.6966e-05,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/654028876 & http://id.who.int/icd/release/11/2019-04/mms/274476426',
#   'title': 'Malignant neoplasm metastasis in anus [Sphincter ani muscle]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/654028876',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D86&XA3ML6',
#   'score': 2.1912551e-07,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "anal <em class='found'>sphincter</em> metastasis [<em class='found'>Sphincter</em> <em class='found'>ani</em> <em class='found'>muscle</em>]",
#     'score': 2.1912551e-07,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/654028876 & http://id.who.int/icd/release/11/2019-04/mms/1594277606',
#   'title': 'Malignant neoplasm metastasis in anus [Anal Canal]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/654028876',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D86&XA39S6',
#   'score': 0.00011402184,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>anal</em> sphincter metastasis [<em class='found'>Anal</em> C<em class='found'>anal</em>]",
#     'score': 0.00011402184,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/315445782/unspecified & http://id.who.int/icd/release/11/2019-04/mms/64097017',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasms</em> of peritoneum, unspecified [<em class='found'>Mesocolon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/315445782/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2C51.Z&XA4QM7',
#   'score': 6.220129e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasms</em> of peritoneum [<em class='found'>Mesocolon</em>]",
#     'score': 6.220129e-05,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/1777850685',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [Ascending <em class='found'>colon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA3AL5',
#   'score': 4.085191e-15,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [Ascending <em class='found'>colon</em>]",
#     'score': 4.085191e-15,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/2128592381',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Transverse</em> <em class='found'>colon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA49U1',
#   'score': 9.956576e-15,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [<em class='found'>Transverse</em> <em class='found'>colon</em>]",
#     'score': 9.956576e-15,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/453411773',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [Descending <em class='found'>colon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA2G13',
#   'score': 4.085191e-15,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [Descending <em class='found'>colon</em>]",
#     'score': 4.085191e-15,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/894847549',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Sigmoid</em> <em class='found'>colon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA8YJ9',
#   'score': 1.0252972e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [<em class='found'>Sigmoid</em> <em class='found'>colon</em>]",
#     'score': 1.0252972e-14,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Sigmoid</em> flexure of <em class='found'>colon</em>]",
#     'score': 2.6102455e-19,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [<em class='found'>Sigmoid</em> flexure of <em class='found'>colon</em>]",
#     'score': 2.6102455e-19,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/328294343',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> <em class='found'>metastasis</em> in large intestine [<em class='found'>Hepatic</em> flexure of colon]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA95L3',
#   'score': 9.9140895e-15,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> <em class='found'>metastasis</em> in large intestine [<em class='found'>Hepatic</em> flexure]",
#     'score': 9.9140895e-15,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/204400509',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [Splenic flexure of <em class='found'>colon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA1PY9',
#   'score': 1.04715967e-19,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [Splenic flexure of <em class='found'>colon</em>]",
#     'score': 1.04715967e-19,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/1614204137',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Descending</em> <em class='found'><em class='found'>colon</em></em> and <em class='found'>splenic</em> <em class='found'>flexure</em> of <em class='found'><em class='found'>colon</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA7177',
#   'score': 2.8114013e-24,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Secondary <em class='found'>malignant</em> <em class='found'>neoplasm</em> of large intestine [<em class='found'>Descending</em> <em class='found'><em class='found'>colon</em></em> and <em class='found'>splenic</em> <em class='found'>flexure</em> of <em class='found'><em class='found'>colon</em></em>]",
#     'score': 2.8114013e-24,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/1431962259',
#   'title': 'Malignant neoplasm metastasis in large intestine [Ascending colon and right flexure of colon]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA25P9',
#   'score': 1.9333823e-24,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> <em class='found'>metastasis</em> in large intestine [ascending colon and <em class='found'>hepatic</em> flexure of colon]",
#     'score': 1.9333823e-24,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/400097321 & http://id.who.int/icd/release/11/2019-04/mms/578694909',
#   'title': "<em class='found'>Malignant</em> <em class='found'>neoplasm</em> metastasis in large intestine [<em class='found'>Colon</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/400097321',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2D85&XA03U9',
#   'score': 3.40298e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
# ...
#     'score': 8.60748e-15,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639 & http://id.who.int/icd/release/11/2019-04/mms/1258739502',
#   'title': "Basal cell carcinoma of <em class='found'><em class='found'>lip</em></em> [<em class='found'>Vermilion</em> of <em class='found'>lower</em> <em class='found'><em class='found'>lip</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B60.0&XA7H02',
#   'score': 1.0388213e-10,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639 & http://id.who.int/icd/release/11/2019-04/mms/1920891502',
#   'title': 'Basal cell carcinoma of lip [Labial mucosa of lower lip]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B60.0&XA72W2',
#   'score': 1.1836051e-14,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Basal cell carcinoma of <em class='found'><em class='found'>lip</em></em> [<em class='found'>Inner</em> <em class='found'>aspect</em> of <em class='found'>lower</em> <em class='found'><em class='found'>lip</em></em>]",
#     'score': 1.1836051e-14,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639 & http://id.who.int/icd/release/11/2019-04/mms/1262821408',
#   'title': "Basal cell carcinoma of <em class='found'><em class='found'>lip</em></em> [<em class='found'>Skin</em> of <em class='found'>upper</em> <em class='found'><em class='found'>lip</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B60.0&XA0LL8',
#   'score': 9.590374e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639 & http://id.who.int/icd/release/11/2019-04/mms/1181748768',
#   'title': "Basal cell carcinoma of <em class='found'><em class='found'>lip</em></em> [<em class='found'>Skin</em> of <em class='found'>lower</em> <em class='found'><em class='found'>lip</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B60.0&XA7DN8',
#   'score': 9.532152e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639 & http://id.who.int/icd/release/11/2019-04/mms/1868197171',
#   'title': "Basal cell carcinoma of <em class='found'><em class='found'>lip</em></em> [<em class='found'>Vermilion</em> border of <em class='found'>upper</em> <em class='found'><em class='found'>lip</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B60.0&XA8RK1',
#   'score': 1.079674e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639 & http://id.who.int/icd/release/11/2019-04/mms/710013012',
#   'title': "Basal cell carcinoma of <em class='found'><em class='found'>lip</em></em> [<em class='found'>Vermilion</em> border of <em class='found'>lower</em> <em class='found'><em class='found'>lip</em></em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/2044047639',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B60.0&XA9TK2',
#   'score': 1.0743412e-14,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1784082025',
#   'title': "Malignant neoplasms of lingual <em class='found'>tonsil</em>",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1784082025',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B62.1',
#   'score': 0.010433771,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "lingual <em class='found'>tonsil</em> cancer",
#     'score': 0.010433771,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "lingual <em class='found'>tonsillar</em> cancer",
#     'score': 0.010433771,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary malignant neoplasm of lingual <em class='found'>tonsil</em>",
#     'score': 1.3938474e-07,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1719710858/unspecified & http://id.who.int/icd/release/11/2019-04/mms/1682501833',
#   'title': 'Malignant neoplasms of gum, unspecified [Gingivae]',
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1719710858/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2B63.Z&XA54T3',
#   'score': 0.000107121195,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>upper</em> <em class='found'>gum</em> cancer [Gingivae]",
#     'score': 0.000107121195,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary malignant neoplasm of <em class='found'>upper</em> <em class='found'>gum</em> [Gingivae]",
#     'score': 7.939788e-11,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/446537607 & http://id.who.int/icd/release/11/2019-04/mms/1682501833',
#   'title': "Squamous cell carcinoma of <em class='found'>gum</em> [Gingivae]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/446537607',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B63.0&XA54T3',
#   'score': 1.7537023e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1719710858/other & http://id.who.int/icd/release/11/2019-04/mms/1682501833',
#   'title': "Other specified malignant neoplasm of <em class='found'>gum</em> [Gingivae]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1719710858/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B63.Y&XA54T3',
#   'score': 1.7537023e-07,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/826670225/other & http://id.who.int/icd/release/11/2019-04/mms/1781206950',
#   'title': "Other specified malignant neoplasms of <em class='found'>hypopharynx</em> [Piriform <em class='found'>recess</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/826670225/other',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B6D.Y&XA3MZ0',
#   'score': 4.913393e-11,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/826670225/unspecified & http://id.who.int/icd/release/11/2019-04/mms/1781206950',
#   'title': "Malignant neoplasms of <em class='found'>hypopharynx</em>, unspecified [Piriform <em class='found'>recess</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/826670225/unspecified',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '02',
#   'theCode': '2B6D.Z&XA3MZ0',
#   'score': 6.560657e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "<em class='found'>hypopharyngeal</em> cancer [Piriform <em class='found'>recess</em>]",
#     'score': 6.560657e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Malignant neoplasms of <em class='found'>hypopharynx</em> [Piriform <em class='found'>recess</em>]",
#     'score': 1.1453609e-07,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "malignant neoplasm of <em class='found'>hypopharyngeal</em> wall NOS [Piriform <em class='found'>recess</em>]",
#     'score': 4.913393e-11,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary malignant neoplasm of <em class='found'>hypopharyngeal</em> aspect of aryepiglottic fold [Piriform <em class='found'>recess</em>]",
#     'score': 1.1424529e-24,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "primary malignant neoplasm of <em class='found'>hypopharyngeal</em> aspect of interarytenoid fold [Piriform <em class='found'>recess</em>]",
#     'score': 1.1424529e-24,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/680629191 & http://id.who.int/icd/release/11/2019-04/mms/1781206950',
#   'title': "Squamous cell carcinoma of <em class='found'>hypopharynx</em> and variants [Piriform <em class='found'>recess</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/680629191',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B6D.0&XA3MZ0',
#   'score': 5.8576593e-15,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268 & http://id.who.int/icd/release/11/2019-04/mms/1027002380',
#   'title': "Barrett <em class='found'>adenocarcinoma</em> [Upper third of <em class='found'>oesophagus</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B70.00&XA1180',
#   'score': 9.2292095e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Barrett <em class='found'>adenocarcinoma</em> [Upper <em class='found'>esophagus</em>]",
#     'score': 9.2292095e-05,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268 & http://id.who.int/icd/release/11/2019-04/mms/107997583',
#   'title': "Barrett <em class='found'>adenocarcinoma</em> [Middle third of <em class='found'>oesophagus</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B70.00&XA2BY3',
#   'score': 9.2292095e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Barrett <em class='found'>adenocarcinoma</em> [Middle <em class='found'>esophagus</em>]",
#     'score': 9.2292095e-05,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268 & http://id.who.int/icd/release/11/2019-04/mms/706655436',
#   'title': "Barrett <em class='found'>adenocarcinoma</em> [Lower third of <em class='found'>oesophagus</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B70.00&XA9CB6',
#   'score': 9.2292095e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [{'propertyId': 'IndexTerm',
#     'label': "Barrett <em class='found'>adenocarcinoma</em> [Lower <em class='found'>esophagus</em>]",
#     'score': 9.2292095e-05,
#     'important': False},
#    {'propertyId': 'IndexTerm',
#     'label': "Barrett <em class='found'>adenocarcinoma</em> [Disital third of <em class='found'>esophagus</em>]",
#     'score': 1.5785704e-07,
#     'important': False}],
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268 & http://id.who.int/icd/release/11/2019-04/mms/2143578283',
#   'title': "Barrett <em class='found'>adenocarcinoma</em> [Cervical <em class='found'>oesophagus</em>]",
#   'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/1934528268',
#   'isLeaf': False,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '02',
#   'theCode': '2B70.00&XA0N03',
#   'score': 9.2292095e-05,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 2,
#   'important': False,
#   'matchingPVs': [],
#   'descendants': []},
#  ...]

# %%
def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, 'utf-8')
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ")

# %%
datum = data["1D01.Y"]
datum
# Out:
# {'id': 'http://id.who.int/icd/release/11/2019-04/mms/121670633/other',
#  'title': 'Other specified infectious meningitis not elsewhere classified',
#  'stemId': 'http://id.who.int/icd/release/11/2019-04/mms/121670633/other',
#  'isLeaf': True,
#  'postcoordinationAvailability': 2,
#  'hasCodingNote': False,
#  'propertiesTruncated': False,
#  'isResidualOther': True,
#  'isResidualUnspecified': False,
#  'chapter': '01',
#  'theCode': '1D01.Y',
#  'score': 0.38856333,
#  'titleIsASearchResult': False,
#  'titleIsTopScore': False,
#  'entityType': 0,
#  'important': False,
#  'matchingPVs': [{'propertyId': 'IndexTerm',
#    'label': "<em class='found'>adhesive</em> arachnoiditis",
#    'score': 0.38856333,
#    'important': False}],
#  'descendants': []}

# %%
def slugit(text):
    return text.replace('.', '-,-', 1).replace('.', '-').replace('-,-', '.')

# %%
def build_data_xml(data):
    tryton_el = Element('tryton')
    data_el = SubElement(tryton_el, 'data')
    for key, datum in data.items():
        record_el = SubElement(data_el, 'record')
        record_el.set('model', 'gnuhealth.pathology')
        record_el.set('id', slugit("health_icd11.{}".format(datum['theCode'])))


        # data_field_keys = [
        #     'id',
        #     'title',
        #     'stemId',
        #     'theCode',
        # ]
        field_name_el = SubElement(record_el, 'field')
        field_name_el.set('name', 'name')
        field_name_el.text = datum['title']

        field_code_el = SubElement(record_el, 'field')
        field_code_el.set('name', 'code')
        field_code_el.text = datum['theCode']

        field_category_el = SubElement(record_el, 'field')
        field_category_el.set('name', 'category')
        field_category_el.set('ref', slugit('icd11cat{}'.format(datum['chapter'])) )

        field_title_el = SubElement(record_el, 'field')
        field_title_el.set('name', 'active')
        field_title_el.set('eval', 'True')

        field_classifier_el = SubElement(record_el, 'field')
        field_classifier_el.set('name', 'classifier')
        field_classifier_el.text = 'ICD11'
    return tryton_el

# %%
def build_categories_xml(data):
    tryton_el = Element('tryton')
    data_el = SubElement(tryton_el, 'data')
    for key, text in data.items():
        record_el = SubElement(data_el, 'record')
        record_el.set('model', 'gnuhealth.pathology.category')
        record_el.set('id', slugit("icd11cat{}".format(key)))

        field_name_el = SubElement(record_el, 'field')
        field_name_el.set('name', 'name')
        field_name_el.text = text

        field_classifier_el = SubElement(record_el, 'field')
        field_classifier_el.set('name', 'classifier')
        field_classifier_el.text = 'ICD11'
    return tryton_el

# %%
xml_data = build_data_xml(data)
pretty_xml_data = prettify(xml_data)
print(pretty_xml_data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
tree = ElementTree.ElementTree(ElementTree.fromstring(pretty_xml_data))
tree.write('icd11.xml',encoding="UTF-8",xml_declaration=True)

# %%
categories = { '10': '10 Diseases of the ear or mastoid process',
  '11': '11 Diseases of the circulatory system',
  '12': '12 Diseases of the respiratory system',
  '13': '13 Diseases of the digestive system',
  '14': '14 Diseases of the skin',
  '15': '15 Diseases of the musculoskeletal system or connective tissue',
  '16': '16 Diseases of the genitourinary system',
  '17': '17 Conditions related to sexual health',
  '18': '18 Pregnancy, childbirth or the puerperium',
  '19': '19 Certain conditions originating in the perinatal period',
  '20': '20 Developmental anomalies',
  '21': '21 Symptoms, signs or clinical findings, not elsewhere classified',
  '22': '22 Injury, poisoning or certain other consequences of external causes',
  '23': '23 External causes of morbidity or mortality',
  '24': '24 Factors influencing health status or contact with health services',
  '25': '25 Codes for special purposes',
  '26': '26 Supplementary Chapter Traditional Medicine Conditions - Module I',
  '01': '01 Certain infectious or parasitic diseases',
  '02': '02 Neoplasms',
  '03': '03 Diseases of the blood or blood-forming organs',
  '04': '04 Diseases of the immune system',
  '05': '05 Endocrine, nutritional or metabolic diseases',
  '06': '06 Mental, behavioural or neurodevelopmental disorders',
  '07': '07 Sleep-wake disorders',
  '08': '08 Diseases of the nervous system',
  '09': '09 Diseases of the visual system',
  'V': 'V Supplementary section for functioning assessment',
  'X': 'X Extension Codes' }

# %%
xml_category = build_categories_xml(categories)
pretty_xml_category = prettify(xml_category)
print(pretty_xml_category)
# Out:
# <?xml version="1.0" ?>
# <tryton>
#   <data>
#     <record id="icd11cat10" model="gnuhealth.pathology.category">
#       <field name="name">10 Diseases of the ear or mastoid process</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat11" model="gnuhealth.pathology.category">
#       <field name="name">11 Diseases of the circulatory system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat12" model="gnuhealth.pathology.category">
#       <field name="name">12 Diseases of the respiratory system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat13" model="gnuhealth.pathology.category">
#       <field name="name">13 Diseases of the digestive system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat14" model="gnuhealth.pathology.category">
#       <field name="name">14 Diseases of the skin</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat15" model="gnuhealth.pathology.category">
#       <field name="name">15 Diseases of the musculoskeletal system or connective tissue</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat16" model="gnuhealth.pathology.category">
#       <field name="name">16 Diseases of the genitourinary system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat17" model="gnuhealth.pathology.category">
#       <field name="name">17 Conditions related to sexual health</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat18" model="gnuhealth.pathology.category">
#       <field name="name">18 Pregnancy, childbirth or the puerperium</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat19" model="gnuhealth.pathology.category">
#       <field name="name">19 Certain conditions originating in the perinatal period</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat20" model="gnuhealth.pathology.category">
#       <field name="name">20 Developmental anomalies</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat21" model="gnuhealth.pathology.category">
#       <field name="name">21 Symptoms, signs or clinical findings, not elsewhere classified</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat22" model="gnuhealth.pathology.category">
#       <field name="name">22 Injury, poisoning or certain other consequences of external causes</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat23" model="gnuhealth.pathology.category">
#       <field name="name">23 External causes of morbidity or mortality</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat24" model="gnuhealth.pathology.category">
#       <field name="name">24 Factors influencing health status or contact with health services</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat25" model="gnuhealth.pathology.category">
#       <field name="name">25 Codes for special purposes</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat26" model="gnuhealth.pathology.category">
#       <field name="name">26 Supplementary Chapter Traditional Medicine Conditions - Module I</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat01" model="gnuhealth.pathology.category">
#       <field name="name">01 Certain infectious or parasitic diseases</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat02" model="gnuhealth.pathology.category">
#       <field name="name">02 Neoplasms</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat03" model="gnuhealth.pathology.category">
#       <field name="name">03 Diseases of the blood or blood-forming organs</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat04" model="gnuhealth.pathology.category">
#       <field name="name">04 Diseases of the immune system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat05" model="gnuhealth.pathology.category">
#       <field name="name">05 Endocrine, nutritional or metabolic diseases</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat06" model="gnuhealth.pathology.category">
#       <field name="name">06 Mental, behavioural or neurodevelopmental disorders</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat07" model="gnuhealth.pathology.category">
#       <field name="name">07 Sleep-wake disorders</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat08" model="gnuhealth.pathology.category">
#       <field name="name">08 Diseases of the nervous system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11cat09" model="gnuhealth.pathology.category">
#       <field name="name">09 Diseases of the visual system</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11catV" model="gnuhealth.pathology.category">
#       <field name="name">V Supplementary section for functioning assessment</field>
#       <field name="classifier">ICD11</field>
#     </record>
#     <record id="icd11catX" model="gnuhealth.pathology.category">
#       <field name="name">X Extension Codes</field>
#       <field name="classifier">ICD11</field>
#     </record>
#   </data>
# </tryton>

# %%
tree = ElementTree.ElementTree(ElementTree.fromstring(pretty_xml_category))
tree.write('icd11_disease_categories.xml',encoding="UTF-8",xml_declaration=True)

# %%
strs = 'a.b.c.d'
count = 1
strs = strs.replace('.', '-,-', count).replace('.', '-').replace('-,-', '.')
strs
# Out:
# 'a.b-c-d'
